# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
airfare_raw = pd.read_csv("/Users/alexmahadevan/Code/Projects/airfare/Consumer_Airfare_Report__Table_1_-_Top_1_000_Contiguous_State_City-Pair_Markets.csv")

# %%
airfare_raw.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2  \
# 0  2009        2           32467           34576
# 1  2000        4           30397           33198
# 2  2007        4           32575           34614
# 3  2004        4           32337           31650
# 4  2008        4           30194           30559
#
#                                  city1                     city2  nsmiles  \
# 0        Miami, FL (Metropolitan Area)             Rochester, NY     1204
# 1      Atlanta, GA (Metropolitan Area)           Kansas City, MO      692
# 2  Los Angeles, CA (Metropolitan Area)        Salt Lake City, UT      590
# 3                     Indianapolis, IN  Minneapolis/St. Paul, MN      503
# 4                Dallas/Fort Worth, TX               Seattle, WA     1670
#
#    passengers    fare carrier_lg  large_ms   fare_lg carrier_low  lf_ms  \
# 0         203  151.46         FL      0.29  $131.05           FL   0.29
# 1         782  172.83         DL      0.63  $194.71           NJ   0.26
# ...

# %%
airfare_recent = airfare_raw[airfare_raw['Year'] == 2016]

# %%
airfare_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 76019 to 86019
# Data columns (total 18 columns):
# Year              4000 non-null int64
# quarter           4000 non-null int64
# citymarketid_1    4000 non-null int64
# citymarketid_2    4000 non-null int64
# city1             4000 non-null object
# city2             4000 non-null object
# nsmiles           4000 non-null int64
# passengers        4000 non-null int64
# fare              4000 non-null float64
# carrier_lg        4000 non-null object
# large_ms          4000 non-null float64
# fare_lg           4000 non-null object
# carrier_low       4000 non-null object
# lf_ms             4000 non-null float64
# fare_low          4000 non-null object
# table_1_flag      4000 non-null int64
# Geocoded_City1    4000 non-null object
# Geocoded_City2    4000 non-null object
# dtypes: float64(3), int64(7), object(8)
# memory usage: 593.8+ KB

# %%
airfare_most_recent = airfare_recent[airfare_recent['quarter'] == 2]

# %%
airfare_most_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 76024 to 86003
# Data columns (total 18 columns):
# Year              1000 non-null int64
# quarter           1000 non-null int64
# citymarketid_1    1000 non-null int64
# citymarketid_2    1000 non-null int64
# city1             1000 non-null object
# city2             1000 non-null object
# nsmiles           1000 non-null int64
# passengers        1000 non-null int64
# fare              1000 non-null float64
# carrier_lg        1000 non-null object
# large_ms          1000 non-null float64
# fare_lg           1000 non-null object
# carrier_low       1000 non-null object
# lf_ms             1000 non-null float64
# fare_low          1000 non-null object
# table_1_flag      1000 non-null int64
# Geocoded_City1    1000 non-null object
# Geocoded_City2    1000 non-null object
# dtypes: float64(3), int64(7), object(8)
# memory usage: 148.4+ KB

# %%
airfare_most_recent.sort_values('fare', ascending=False)
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 78827  2016        2           34100           32457
# 83483  2016        2           31703           32457
# 78484  2016        2           33105           31650
# 82058  2016        2           32457           30852
# 81815  2016        2           32575           31703
# 79449  2016        2           31703           34262
# 80518  2016        2           30529           31453
# 76510  2016        2           32575           33044
# 85139  2016        2           31066           31453
# 76024  2016        2           30721           32457
# 85378  2016        2           31057           32457
# 81934  2016        2           30198           32457
# 82850  2016        2           31453           34100
# 78882  2016        2           30977           31834
# 78538  2016        2           31295           32457
# 82646  2016        2           30721           33105
# 85936  2016        2           32575           33667
# ...

# %%
airfare_most_recent['cost_per_mile'] = airfare_most_recent['fare'] / airfare_most_recent['nsmiles']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
airfare_most_recent.head()
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 76024  2016        2           30721           32457
# 76026  2016        2           30466           30559
# 76033  2016        2           30325           30693
# 76037  2016        2           32575           30928
# 76043  2016        2           33342           32457
#
#                                      city1  \
# 76024       Boston, MA (Metropolitan Area)
# 76026                          Phoenix, AZ
# 76033                           Denver, CO
# 76037  Los Angeles, CA (Metropolitan Area)
# 76043                        Milwaukee, WI
#
#                                        city2  nsmiles  passengers    fare  \
# 76024  San Francisco, CA (Metropolitan Area)     2704        4136  345.67
# 76026                            Seattle, WA     1107        2286  181.11
# 76033                          Nashville, TN     1014         940  193.69
# 76037                            Wichita, KS     1203         214  236.04
# ...

# %%
airfare_most_recent['path'] = airfare_most_recent['city1'] + '-->' + airfare_most_recent['city2']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
airfare_most_recent.sort_values('passengers', ascending=True)
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 80518  2016        2           30529           31453
# 85297  2016        2           33667           33195
# 81199  2016        2           30397           30994
# 85178  2016        2           31136           30559
# 78334  2016        2           33192           31123
# 80335  2016        2           30397           31834
# 85570  2016        2           31295           33342
# 83396  2016        2           31136           30466
# 83428  2016        2           32337           34057
# 77364  2016        2           33198           33192
# 81507  2016        2           32575           33485
# 83910  2016        2           30257           30325
# 85077  2016        2           31057           33192
# 80839  2016        2           33316           33570
# 77056  2016        2           30721           31267
# 82530  2016        2           30397           34653
# 81046  2016        2           33244           30466
# ...

# %%
airfare_most_recent['passengers'].quantile(q=0.9)
# Out:
# 2218.4

# %%
frequent_flights = airfare_most_recent[airfare_most_recent['passengers'] >= 2247.2]

# %%
frequent_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 76024 to 85962
# Data columns (total 20 columns):
# Year              99 non-null int64
# quarter           99 non-null int64
# citymarketid_1    99 non-null int64
# citymarketid_2    99 non-null int64
# city1             99 non-null object
# city2             99 non-null object
# nsmiles           99 non-null int64
# passengers        99 non-null int64
# fare              99 non-null float64
# carrier_lg        99 non-null object
# large_ms          99 non-null float64
# fare_lg           99 non-null object
# carrier_low       99 non-null object
# lf_ms             99 non-null float64
# fare_low          99 non-null object
# table_1_flag      99 non-null int64
# Geocoded_City1    99 non-null object
# Geocoded_City2    99 non-null object
# cost_per_mile     99 non-null float64
# path              99 non-null object
# dtypes: float64(4), int64(7), object(9)
# memory usage: 16.2+ KB

# %%
frequent_flights.sort_values('cost_per_mile')
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 84827  2016        2           32575           31454
# 84539  2016        2           32575           32467
# 84396  2016        2           32211           30852
# 77615  2016        2           30977           32211
# 78638  2016        2           30721           32575
# 81445  2016        2           30397           32211
# 85145  2016        2           31703           30466
# 78135  2016        2           32575           30852
# 85418  2016        2           32575           34100
# 80060  2016        2           31703           30559
# 76996  2016        2           32211           31703
# 82548  2016        2           30977           32575
# 78366  2016        2           30977           30559
# 76415  2016        2           30977           32457
# 76459  2016        2           30977           30466
# 76024  2016        2           30721           32457
# 84000  2016        2           30397           32575
# ...

# %%
top_most_expensive = frequent_flights.nlargest(10, 'cost_per_mile')

# %%
top_most_expensive.plot(kind="bar", x="path", y="cost_per_mile")

# %%
top_least_expensive = frequent_flights.nsmallest(10, 'cost_per_mile')

# %%
top_least_expensive.plot(kind="bar", x="path", y="cost_per_mile")

# %%
frequent_flights.plot(kind='scatter', x='fare', y='passengers')

# %%
frequent_flights.plot(kind='scatter', x='fare', y='nsmiles')

# %%
airfare_raw['nsmiles'].quantile(0.1)
# Out:
# 365.0

# %%
short_flights = airfare_raw[airfare_raw['nsmiles'] <= 365]

# %%
short_flights.sort_values('passengers', ascending=False)
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 4780   2007        3           32211           32575
# 52717  2005        3           32211           32575
# 55611  2006        3           32211           32575
# 58697  2006        2           32211           32575
# 26669  2007        2           32211           32575
# 58610  2006        4           32211           32575
# 59619  2000        2           30721           31703
# 26207  2008        2           32211           32575
# 71157  2008        1           32211           32575
# 1311   2006        1           32211           32575
# 17502  2000        4           30721           31703
# 4033   2005        4           32211           32575
# 57055  2005        2           32211           32575
# 56432  2007        1           32211           32575
# 11589  2007        4           32211           32575
# 46293  1999        4           30721           31703
# 72188  2000        3           30721           31703
# ...

# %% [markdown]
# ## We are restarting the analysis with the whole dataset

# %%
airfare_raw['cost_per_mile'] = airfare_raw['fare'] / airfare_raw['nsmiles']

# %%
airfare_raw['geo'] = airfare_raw.Geocoded_City1.apply(lambda x: x.split('\r')[1].split(','))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
most_recent.head()
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2            city1  \
# 76040  2017        2           30713           30559        Boise, ID
# 76065  2017        2           30325           31650       Denver, CO
# 76086  2017        2           33044           33195   Louisville, KY
# 76106  2017        2           33214           30559  San Antonio, TX
# 76108  2017        2           34321           30852     Portland, ME
#
#                                     city2  nsmiles  passengers    fare  \
# 76040                         Seattle, WA      399         809  130.78
# 76065            Minneapolis/St. Paul, MN      680        2259  137.97
# 76086       Tampa, FL (Metropolitan Area)      729         314  186.62
# 76106                         Seattle, WA     1774         445  237.28
# 76108  Washington, DC (Metropolitan Area)      493         523  188.65
#
#       carrier_lg             ...               lf_ms  fare_low table_1_flag  \
# ...

# %%
airfare_raw.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2  \
# 0  2009        2           32467           34576
# 1  2000        4           30397           33198
# 2  2007        4           32575           34614
# 3  2004        4           32337           31650
# 4  2008        4           30194           30559
#
#                                  city1                     city2  nsmiles  \
# 0        Miami, FL (Metropolitan Area)             Rochester, NY     1204
# 1      Atlanta, GA (Metropolitan Area)           Kansas City, MO      692
# 2  Los Angeles, CA (Metropolitan Area)        Salt Lake City, UT      590
# 3                     Indianapolis, IN  Minneapolis/St. Paul, MN      503
# 4                Dallas/Fort Worth, TX               Seattle, WA     1670
#
#    passengers    fare carrier_lg  large_ms   fare_lg carrier_low  lf_ms  \
# 0         203  151.46         FL      0.29  $131.05           FL   0.29
# 1         782  172.83         DL      0.63  $194.71           NJ   0.26
# ...

# %%
airfare_raw['cost_per_passenger'] = airfare_raw['fare'] / airfare_raw['passengers']

# %%
airfare_raw['path'] = airfare_raw['city1'] + '-->' + airfare_raw['city2']

# %%
# tk = airfare_raw[airfare_raw['Year'] == 2001]

# %%
# tk = last_year[last_year['quarter'] == 4]

# %%
airfare_raw.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2  \
# 0  2009        2           32467           34576
# 1  2000        4           30397           33198
# 2  2007        4           32575           34614
# 3  2004        4           32337           31650
# 4  2008        4           30194           30559
#
#                                  city1                     city2  nsmiles  \
# 0        Miami, FL (Metropolitan Area)             Rochester, NY     1204
# 1      Atlanta, GA (Metropolitan Area)           Kansas City, MO      692
# 2  Los Angeles, CA (Metropolitan Area)        Salt Lake City, UT      590
# 3                     Indianapolis, IN  Minneapolis/St. Paul, MN      503
# 4                Dallas/Fort Worth, TX               Seattle, WA     1670
#
#    passengers    fare carrier_lg  large_ms   fare_lg carrier_low  lf_ms  \
# 0         203  151.46         FL      0.29  $131.05           FL   0.29
# 1         782  172.83         DL      0.63  $194.71           NJ   0.26
# ...

# %%
last_year = airfare_raw[airfare_raw['Year'] == 2017]

# %%
most_recent = last_year[last_year['quarter'] == 2]

# %%
most_recent.sort_values('cost_per_passenger')
# Out:
#        Year  quarter  citymarketid_1  citymarketid_2  \
# 76398  2017        2           32575           32457
# 80170  2017        2           32467           31703
# 81210  2017        2           31703           31454
# 83136  2017        2           30977           31703
# 80022  2017        2           32575           30559
# 79651  2017        2           32211           32457
# 78336  2017        2           32211           32575
# 78516  2017        2           30721           30852
# 84568  2017        2           33570           32457
# 80629  2017        2           32467           30852
# 78178  2017        2           32457           30559
# 82034  2017        2           32575           34057
# 76689  2017        2           30325           32575
# 85152  2017        2           31454           30852
# 77162  2017        2           32575           33192
# 80258  2017        2           30397           31703
# 78427  2017        2           30977           32575
# ...

# %%
for i in most_recent.Geocoded_City1:
    print(i)
# Out:
# (43.597772, -83.884521)
# (39.738453, -104.984853)
# (38.256078, -85.751569)
# (29.425173, -98.494599)
# (45.516018, -122.681425)
# (30.185159, -85.73078)
# (35.222936, -80.840161)
# (41.775002, -87.696388)
# (28.538331, -81.378879)
# (29.950621, -90.074948)
# (35.084248, -106.649241)
# (39.104427, -84.513808)
# (39.738453, -104.984853)
# (39.951061, -75.16562)
# (40.123164, -75.333718)
# (42.332916, -83.047853)
# (35.207009, -101.832013)
# (36.169202, -115.140597)
# (30.264979, -97.746598)
# (30.264979, -97.746598)
# (41.775002, -87.696388)
# (41.765775, -72.673356)
# (43.597772, -83.884521)
# (35.084248, -106.649241)
# (44.977479, -93.264346)
# (46.07035, -93.666319)
# (41.765775, -72.673356)
# (35.143378, -90.052136)
# (41.775002, -87.696388)
# (31.76006, -106.492257)
# (45.516018, -122.681425)
# (42.358894, -71.056742)
# (42.358894, -71.056742)
# (44.977479, -93.264346)
# (34.052238, -118.243344)
# (34.052238, -118.243344)
# (33.748547, -84.391502)
# (36.169202, -115.140597)
# ...

# %%
def price_limit(limit, array):
    if array > limit:
        print("This is wrong.")

# %%
print(most_recent.Geocoded_City1)
# Out:
# 76040                   Boise, ID\r(43.597772, -83.884521)
# 76065                 Denver, CO\r(39.738453, -104.984853)
# 76086              Louisville, KY\r(38.256078, -85.751569)
# 76106             San Antonio, TX\r(29.425173, -98.494599)
# 76108               Portland, ME\r(45.516018, -122.681425)
# 76133              Panama City, FL\r(30.185159, -85.73078)
# 76139               Charlotte, NC\r(35.222936, -80.840161)
# 76143                 Chicago, IL\r(41.775002, -87.696388)
# 76163                 Orlando, FL\r(28.538331, -81.378879)
# 76174             New Orleans, LA\r(29.950621, -90.074948)
# 76199            Albuquerque, NM\r(35.084248, -106.649241)
# 76200              Cincinnati, OH\r(39.104427, -84.513808)
# 76211                 Denver, CO\r(39.738453, -104.984853)
# 76235             Philadelphia, PA\r(39.951061, -75.16562)
# 76247    New York City, NY (Metropolitan Area)\r(40.123...
# 76255                 Detroit, MI\r(42.332916, -83.047853)
# ...
